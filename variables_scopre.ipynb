# %%
def performAction(action, *args, **kwargs):
    print(f"Performing action: {action}")
    print(f"Positional arguments: {args}")
    print(f"Keyword arguments: {kwargs}")

performAction('greet', 'Hello', name='Alice', age=30)
# Out:
# Performing action: greet
# Positional arguments: ('Hello',)
# Keyword arguments: {'name': 'Alice', 'age': 30}

# %%
def myFunction(num1, num2):
    print(locals())

myFunction(5, 10)
# Out:
# {'num1': 5, 'num2': 10}

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'def performAction(action, *args, **kwargs):\n    print(f"Performing action: {action}")\n    print(f"Positional arguments: {args}")\n    print(f"Keyword arguments: {kwargs}")\n\nperformAction(\'greet\', \'Hello\', name=\'Alice\', age=30)',
#   'def myFunction(num1, num2):\n    print(locals)',
#   'def myFunction(num1, num2):\n    print(locals)\n\nmyFunction(5, 10)',
#   'def myFunction(num1, num2):\n    print(locals())\n\nmyFunction(5, 10)',
#   'globals()'],
#  '_oh': {},
#  '_dh': [WindowsPath('c:/Users/mirfan25/Workspace/python_play')],
#  'In': ['',
# ...

# %%
message = "Hello, World!"

def myFunction(varA, varB):
    print("Inside function:", varA, varB)
    print("Inside function:", message)

def myFunction2(varC, varD):
    print("Inside function:", varC, varD)
    print("Inside function:", message)
    print("second function")


myFunction(10, 20)
myFunction2(30, 40)
# Out:
# Inside function: 10 20
# Inside function: Hello, World!
# Inside function: 30 40
# Inside function: Hello, World!
# second function

# %%
def myFunction(varA, varB):
    print('This is a function')
    message = "Hello, World!"
    print(locals())

    def innerFunction(varA, varB):
        print('This is an inner function')
        print(locals())

    print(locals())
    innerFunction(10, 20)

myFunction(5, 10)
# Out:
# This is a function
# {'varA': 5, 'varB': 10, 'message': 'Hello, World!'}
# {'varA': 5, 'varB': 10, 'message': 'Hello, World!', 'innerFunction': <function myFunction.<locals>.innerFunction at 0x000001BC88E8D010>}
# This is an inner function
# {'varA': 10, 'varB': 20}

# %%
text = '''
Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way to do it.
Although that way may not be obvious at first unless you're Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good idea.
Namespaces are one honking great idea -- let's do more of those!
'''

# %%
text = '''
Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way to do it.
Although that way may not be obvious at first unless you're Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good idea.
Namespaces are one honking great idea -- let's do more of those!
'''

def lowercase(txt):
    return txt.lower()
def removePunctuation(txt):
    punctuations = ['.', '-', ',', '*']
    for p in punctuations:
        txt = txt.replace(p, '')
    return txt
def countWords(txt):
    wordCounts = {}
    words = txt.split()
    for word in words:
        if word in wordCounts:
            wordCounts[word] += 1
        else:
            wordCounts[word] = 1
    return wordCounts

def removeNewlines(txt):
    return txt.replace('\n', ' ')

def shortenWords(txt):
    return ' '.join([word for word in txt.split() if len(word) > 3])

def removeLongWords(txt):
    return ' '.join([word for word in txt.split() if len(word) < 6])


processingFunctions = [lowercase, removePunctuation, removeNewlines, removeLongWords]

for func in processingFunctions:
    text = func(text)

print(text)
# Out:
# is than ugly is than is than is than flat is than is than dense cases to break the rules beats never pass in the face of the to guess there be one and only one way to do it that way may not be at first dutch now is than never never is often than right now if the is hard to it's a bad idea if the is easy to it may be a good idea are one great idea let's do more of

# %%
#lambda functions

2+3
# Out:
# 5

# %%
(lambda x, y: x + y)(2, 3)
# Out:
# 5

# %%
myList = [7,2,4,6,1,8]
sorted(myList)
# Out:
# [1, 2, 4, 6, 7, 8]

# %%
myList = [{'key1': 5}, {'key1': 3}, {'key1': 6}]
sorted(myList, key=lambda x: x['key1'])
# Out:
# [{'key1': 3}, {'key1': 5}, {'key1': 6}]
