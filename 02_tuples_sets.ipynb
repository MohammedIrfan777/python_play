# %%
myset = {'a', 'b', 'c', 'd'}
print(myset)
# Out:
# {'b', 'd', 'a', 'c'}

# %%
myset = set({'a', 'b', 'c', 'd'})
print(myset)
# Out:
# {'b', 'd', 'a', 'c'}

# %%
myList = [1,2,3,4,5,6,2,3,4]
print(myList)
myList = list(set(myList))
myList
# Out:
# [1, 2, 3, 4, 5, 6, 2, 3, 4]
# [1, 2, 3, 4, 5, 6]

# %%
myset[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 myset[0]
#
# TypeError: 'set' object is not subscriptable

# %%
myset.add('e')
print(myset)
# Out:
# {'a', 'b', 'c', 'e', 'd'}

# %%
'a' in myset

myset.discard('a')

myset
# Out:
# set()

# %%
while len(myset) > 0:
    myset.pop()
    print(myset)
# Out:
# {'b', 'c', 'e', 'd'}
# {'c', 'e', 'd'}
# {'e', 'd'}
# {'d'}
# set()

# %%
a=(1,2,3,4,5)
type(a)
# Out:
# tuple

# %%
def returnValue():
    return 1,2,3,4,5

a,b,c,d,e = returnValue()

print(a)
print(b)    
print(c)
print(d)
print(e)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
type(returnValue())
# Out:
# tuple
